# %% [markdown]
# # Simulating on NVIDIA Graphics Card with CUDA

# %%
CODE_ROOT = pwd() * "/"
# Out:
# "/home/rrs/Desktop/MPAS_Ocean/"

# %%
include(CODE_ROOT * "mode_init/mode_init.jl")

include(CODE_ROOT * "visualization.jl")

include(CODE_ROOT * "mode_forward/time_steppers.jl")
# Out:
# forward_euler_step_cuda! (generic function with 1 method)

# %%
using PyPlot, PyCall
animation  = pyimport("matplotlib.animation")
ipydisplay = pyimport("IPython.display")
# Out:
# PyObject <module 'IPython.display' from '/home/rrs/anaconda3/envs/MPAS_Ocean/lib/python3.8/site-packages/IPython/display.py'>

# %%
import CUDA

import CUDAKernels

import KernelAbstractions

# %%
CUDA.memory_status()
# Out:
# CUDA error (code 999, CUDA_ERROR_UNKNOWN)
#
# Stacktrace:
#   [1] throw_api_error(res::CUDA.cudaError_enum)
#     @ CUDA ~/.julia/packages/CUDA/02Kjq/lib/cudadrv/error.jl:105
#   [2] macro expansion
#     @ ~/.julia/packages/CUDA/02Kjq/lib/cudadrv/error.jl:115 [inlined]
#   [3] cuInit
#     @ ~/.julia/packages/CUDA/02Kjq/lib/utils/call.jl:26 [inlined]
#   [4] initialize_api
#     @ ~/.julia/packages/CUDA/02Kjq/lib/cudadrv/error.jl:85 [inlined]
#   [5] macro expansion
#     @ ~/.julia/packages/CUDA/02Kjq/lib/cudadrv/libcuda.jl:32 [inlined]
#   [6] macro expansion
#     @ ~/.julia/packages/CUDA/02Kjq/lib/cudadrv/error.jl:111 [inlined]
#   [7] cuDeviceGet(device::Base.RefValue{Int32}, ordinal::Int64)
#     @ CUDA ~/.julia/packages/CUDA/02Kjq/lib/utils/call.jl:26
#   [8] CuDevice
#     @ ~/.julia/packages/CUDA/02Kjq/lib/cudadrv/devices.jl:25 [inlined]
#   [9] TaskLocalState
#     @ ~/.julia/packages/CUDA/02Kjq/src/state.jl:50 [inlined]
#  [10] task_local_state!()
#     @ CUDA ~/.julia/packages/CUDA/02Kjq/src/state.jl:73
#  [11] context
#     @ ~/.julia/packages/CUDA/02Kjq/src/state.jl:122 [inlined]
#  [12] memory_status(io::IJulia.IJuliaStdio{Base.PipeEndpoint}) (repeats 2 times)
#     @ CUDA ~/.julia/packages/CUDA/02Kjq/src/pool.jl:597
#  [13] top-level scope
#     @ In[5]:1
#  [14] eval
#     @ ./boot.jl:360 [inlined]
#  [15] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1094

# %%
const MAX_THREADS_PER_BLOCK = CUDA.attribute(
        CUDA.CuDevice(0), CUDA.DEVICE_ATTRIBUTE_MAX_THREADS_PER_BLOCK,
)
# Out:
# CUDA error (code 999, CUDA_ERROR_UNKNOWN)
#
# Stacktrace:
#   [1] throw_api_error(res::CUDA.cudaError_enum)
#     @ CUDA ~/.julia/packages/CUDA/02Kjq/lib/cudadrv/error.jl:105
#   [2] macro expansion
#     @ ~/.julia/packages/CUDA/02Kjq/lib/cudadrv/error.jl:115 [inlined]
#   [3] cuInit
#     @ ~/.julia/packages/CUDA/02Kjq/lib/utils/call.jl:26 [inlined]
#   [4] initialize_api
#     @ ~/.julia/packages/CUDA/02Kjq/lib/cudadrv/error.jl:85 [inlined]
#   [5] macro expansion
#     @ ~/.julia/packages/CUDA/02Kjq/lib/cudadrv/libcuda.jl:32 [inlined]
#   [6] macro expansion
#     @ ~/.julia/packages/CUDA/02Kjq/lib/cudadrv/error.jl:111 [inlined]
#   [7] cuDeviceGet(device::Base.RefValue{Int32}, ordinal::Int64)
#     @ CUDA ~/.julia/packages/CUDA/02Kjq/lib/utils/call.jl:26
#   [8] CUDA.CuDevice(ordinal::Int64)
#     @ CUDA ~/.julia/packages/CUDA/02Kjq/lib/cudadrv/devices.jl:25
#   [9] top-level scope
#     @ In[6]:1
#  [10] eval
#     @ ./boot.jl:360 [inlined]
#  [11] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1094

# %% [markdown]
# # Load Mesh From File

# %%
mpasOcean = MPAS_Ocean(false, CODE_ROOT * "MPAS_O_Shallow_Water/Mesh+Initial_Condition+Registry_Files/Periodic",
                "base_mesh.nc", "mesh.nc", periodicity="Periodic"
)
typeof(mpasOcean)
# Out:
# MPAS_Ocean

# %% [markdown]
# # Define Initial Condition

# %%
function gaussianInit!(mpasOcean; sx=1/3, sy=1/3, mx=1/2, my=1/2)
    sigmax = mpasOcean.lX*sx
    sigmay = mpasOcean.lY*sy
    
    mux = mpasOcean.lX*mx
    muy = mpasOcean.lY*my
    
    for iCell in 1:mpasOcean.nCells
        mpasOcean.sshCurrent[iCell] = exp( - (mpasOcean.xCell[iCell] - mux)^2 / sigmax^2 - (mpasOcean.yCell[iCell] - muy)^2 / sigmay^2 )
    end
    
    mpasOcean.normalVelocityCurrent .= 0
    
    return nothing
end
# Out:
# gaussianInit! (generic function with 1 method)

# %%
function planeWaveInit!(mpasOcean; rkx = 1, rky = 1)
    kx = rkx * 2 * pi / mpasOcean.lX
    ky = rky * 2 * pi / mpasOcean.lY
    
    for iCell in 1:mpasOcean.nCells
        mpasOcean.sshCurrent[iCell] = cos( kx * mpasOcean.xCell[iCell] + ky * mpasOcean.yCell[iCell] )
    end
    
    mpasOcean.normalVelocityCurrent .= 0
    
    mpasOcean.sshTendency[:] .= mpasOcean.sshCurrent[:]
    mpasOcean.normalVelocityTendency[:] .= mpasOcean.normalVelocityCurrent[:]
    
    return nothing
end
# Out:
# planeWaveInit! (generic function with 1 method)

# %%
moveArrays!(mpasOcean, Array)

planeWaveInit!(mpasOcean) # could also do gaussianInit!

# %%
fig, ax, cbar, col = heatMapMesh(mpasOcean, mpasOcean.sshCurrent)
display(fig)
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %% [markdown]
# # Simulate Wave on GPU

# %%
# simulate and record nFrames snapshots of the SSH
nFrames = 30

sshOverTime = zeros(nFrames, mpasOcean.nCells)

moveArrays!(mpasOcean, CUDA.CuArray)

for i in 1:nFrames
    for j in 1:10
        forward_backward_step_cuda!(mpasOcean)
    end
    sshOverTime[i,:] = mpasOcean.sshCurrent[:]
end
# Out:
# CUDA error (code 999, CUDA_ERROR_UNKNOWN)
#
# Stacktrace:
#   [1] throw_api_error(res::CUDA.cudaError_enum)
#     @ CUDA ~/.julia/packages/CUDA/02Kjq/lib/cudadrv/error.jl:105
#   [2] macro expansion
#     @ ~/.julia/packages/CUDA/02Kjq/lib/cudadrv/error.jl:115 [inlined]
#   [3] cuInit
#     @ ~/.julia/packages/CUDA/02Kjq/lib/utils/call.jl:26 [inlined]
#   [4] initialize_api
#     @ ~/.julia/packages/CUDA/02Kjq/lib/cudadrv/error.jl:85 [inlined]
#   [5] macro expansion
#     @ ~/.julia/packages/CUDA/02Kjq/lib/cudadrv/libcuda.jl:32 [inlined]
#   [6] macro expansion
#     @ ~/.julia/packages/CUDA/02Kjq/lib/cudadrv/error.jl:111 [inlined]
#   [7] cuDeviceGet(device::Base.RefValue{Int32}, ordinal::Int64)
#     @ CUDA ~/.julia/packages/CUDA/02Kjq/lib/utils/call.jl:26
#   [8] CuDevice
#     @ ~/.julia/packages/CUDA/02Kjq/lib/cudadrv/devices.jl:25 [inlined]
#   [9] TaskLocalState
#     @ ~/.julia/packages/CUDA/02Kjq/src/state.jl:50 [inlined]
#  [10] task_local_state!()
#     @ CUDA ~/.julia/packages/CUDA/02Kjq/src/state.jl:73
#  [11] stream
#     @ ~/.julia/packages/CUDA/02Kjq/src/state.jl:380 [inlined]
#  [12] alloc
#     @ ~/.julia/packages/CUDA/02Kjq/src/pool.jl:259 [inlined]
#  [13] CUDA.CuArray{Float64, 1}(#unused#::UndefInitializer, dims::Tuple{Int64})
#     @ CUDA ~/.julia/packages/CUDA/02Kjq/src/array.jl:28
#  [14] CuArray
#     @ ~/.julia/packages/CUDA/02Kjq/src/array.jl:241 [inlined]
#  [15] CUDA.CuArray(A::Vector{Float64})
#     @ CUDA ~/.julia/packages/CUDA/02Kjq/src/array.jl:249
#  [16] moveArrays!(mpasOcean::MPAS_Ocean, array_type::Type{CUDA.CuArray})
#     @ Main ~/Desktop/MPAS_Ocean/mode_init/mode_init.jl:302
#  [17] top-level scope
#     @ In[12]:6
#  [18] eval
#     @ ./boot.jl:360 [inlined]
#  [19] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1094

# %% [markdown]
# ## Animate Simulation

# %%
# move it back to CPU for animation
moveArrays!(mpasOcean, Array)

cMax = maximum(abs.(sshOverTime))

fig, ax, _, col = heatMapMesh(mpasOcean, sshOverTime[1,:], cMin=-cMax, cMax=cMax)

function nextFrame(i)
    col.set_array(sshOverTime[i+1,:])
end

anim = animation.FuncAnimation(fig, nextFrame, frames=nFrames)
# Out:
# PyObject <matplotlib.animation.FuncAnimation object at 0x7fd411418fa0>

# %%
ipydisplay.HTML(anim.to_html5_video())
# Out:
# PyObject <IPython.core.display.HTML object>
